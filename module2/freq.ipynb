# %% [markdown]
# # Analyse frequency distribution of words

# %% [markdown]
# ## Installation des dépendences

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/charalambos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Création d'une liste de stopwords

# %%
from nltk.corpus import stopwords

sw = stopwords.words("french")
sw += ["les", "plus", "cette", "fait", "faire", "être", "deux", "comme", "dont", "tout", 
       "ils", "bien", "sans", "peut", "tous", "après", "ainsi", "donc", "cet", "sous",
       "celle", "entre", "encore", "toutes", "pendant", "moins", "dire", "cela", "non",
       "faut", "trois", "aussi", "dit", "avoir", "doit", "contre", "depuis", "autres",
       "van", "het", "autre", "jusqu"]
sw = set(sw)
print(f"{len(sw)} stopwords used: {sorted(sw)}")
# Out:
# 197 stopwords used: ['ai', 'aie', 'aient', 'aies', 'ainsi', 'ait', 'après', 'as', 'au', 'aura', 'aurai', 'auraient', 'aurais', 'aurait', 'auras', 'aurez', 'auriez', 'aurions', 'aurons', 'auront', 'aussi', 'autre', 'autres', 'aux', 'avaient', 'avais', 'avait', 'avec', 'avez', 'aviez', 'avions', 'avoir', 'avons', 'ayant', 'ayante', 'ayantes', 'ayants', 'ayez', 'ayons', 'bien', 'c', 'ce', 'cela', 'celle', 'ces', 'cet', 'cette', 'comme', 'contre', 'd', 'dans', 'de', 'depuis', 'des', 'deux', 'dire', 'dit', 'doit', 'donc', 'dont', 'du', 'elle', 'en', 'encore', 'entre', 'es', 'est', 'et', 'eu', 'eue', 'eues', 'eurent', 'eus', 'eusse', 'eussent', 'eusses', 'eussiez', 'eussions', 'eut', 'eux', 'eûmes', 'eût', 'eûtes', 'faire', 'fait', 'faut', 'furent', 'fus', 'fusse', 'fussent', 'fusses', 'fussiez', 'fussions', 'fut', 'fûmes', 'fût', 'fûtes', 'het', 'il', 'ils', 'j', 'je', 'jusqu', 'l', 'la', 'le', 'les', 'leur', 'lui', 'm', 'ma', 'mais', 'me', 'mes', 'moi', 'moins', 'mon', 'même', 'n', 'ne', 'non', 'nos', 'notre', 'nous', 'on', 'ont', 'ou', 'par', 'pas', 'pendant', 'peut', 'plus', 'pour', 'qu', 'que', 'qui', 's', 'sa', 'sans', 'se', 'sera', 'serai', 'seraient', 'serais', 'serait', 'seras', 'serez', 'seriez', 'serions', 'serons', 'seront', 'ses', 'soient', 'sois', 'soit', 'sommes', 'son', 'sont', 'sous', 'soyez', 'soyons', 'suis', 'sur', 't', 'ta', 'te', 'tes', 'toi', 'ton', 'tous', 'tout', 'toutes', 'trois', 'tu', 'un', 'une', 'van', 'vos', 'votre', 'vous', 'y', 'à', 'étaient', 'étais', 'était', 'étant', 'étante', 'étantes', 'étants', 'étiez', 'étions', 'été', 'étée', 'étées', 'étés', 'êtes', 'être']

# %% [markdown]
# ## Visualiser les termes les plus fréquents

# %%
path = "/Volumes/Macintosh HD/Data/ADB/all.txt"
limit = 10**8

with open(path, encoding='utf-8') as f:
    text = f.read()[:limit]
    words = nltk.wordpunct_tokenize(text)
    print(f"{len(words)} words found")
    kept = [w.lower() for w in words if len(w) > 2 and w.isalpha() and w.lower() not in sw]
    voc = set(kept)
    print(f"{len(kept)} words kept ({len(voc)} different word forms)")
    fdist = nltk.FreqDist(kept)
    print(fdist.most_common(50))
    fdist.plot(10, cumulative=True)
    print(fdist.hapaxes())
    long_words = [w for w in voc if len(w) > 15]
    print(sorted(long_words))
# Out:
# 25049038 words found
# 6489207 words kept (154565 different word forms)
# [('rue', 64481), ('conseil', 46066), ('francs', 45547), ('ville', 44824), ('collège', 36003), ('section', 29279), ('bruxelles', 27867), ('art', 27570), ('bourgmestre', 25449), ('travaux', 23523), ('administration', 21827), ('rapport', 21400), ('messieurs', 17041), ('demande', 15982), ('hospices', 15814), ('service', 15667), ('question', 15662), ('frais', 15600), ('echevin', 15461), ('somme', 14284), ('communal', 14199), ('séance', 14049), ('prix', 14027), ('dépenses', 13853), ('avis', 13213), ('finances', 13080), ('place', 13079), ('projet', 13048), ('lieu', 12992), ('budget', 12942), ('partie', 12705), ('proposition', 12600), ('publique', 12536), ('compte', 12313), ('police', 12247), ('année', 12081), ('droit', 11464), ('nombre', 11277), ('honorable', 11205), ('dépense', 9771), ('loi', 9771), ('total', 9611), ('point', 9561), ('publics', 9462), ('terrain', 9246), ('société', 9173), ('heures', 9116), ('communale', 8870), ('cas', 8851), ('jour', 8709)]
# aijïfiirailfeiiséaiisietled', 'jnamaaauodïïiafl', 'jnconstitutionnalilé', 'jnlcnanlraswnbks', 'jnornollofinoijioqoiq', 'jnoûjâiiûsîyoflhj', 'joiurkicleolfloo', 'jossemolenbeekst', 'joséphefrariçoise', 'joséphinestéphanie', 'jouirimmédiatement', 'jouissenactueilement', 'journalièresetles', 'jpaespropriétaires', 'jsanscondomiclie', 'jugementdutribunal', 'justicecimetière', 'jyegendagucanden', 'kermesseflamande', 'kervyndelettenhove', 'kgeoîetjhochsteyn', 'kiiaéikriutdebruc', 'kintderoodenbeke', 'kiosquesjournaux', 'kleyiienkelelberg', 'klîcaprrclatroti', 'koekelbergganshoren', 'kunstgenootschap', 'kêscbftostssuieinï', 'labienveillanceavec', 'laboursejeneveuxpas', 'ladrainislration', 'lafamillejarques', 'lafamilletarlier', 'laigttuatiônjfinaiicière', 'laissafinjoteoilb', 'langueflamandepour', 'langueflamandesoit', 'laparolepourindiquerune', 'lapprofondissemenl', 'lareconstruction', 'lareconstructionde', 'lautransformatio', 'lavilîedchruxelles', 'lechevalierwynsderaucourt', 'leconcessionnaire', 'leconessionnaire', 'leconseilcommunaldebruxellesa', 'leconseilfixeraun', 'leconseilordonne', 'ledernierexercice', 'legouvernementferailluminerleboulevardctlejardinbotanique', 'leipzigjpotamment', 'lelraitementdugrade', 'lepaiementdessalaires', 'lequartieravoisinant', 'lequelfigurepour', 'lequelfigureraientau', '